# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/datosTFM/Valencia/ayudas y subvenciones valencia.csv',sep=';', decimal=',',encoding='utf-8')
df
# Out:
#     CD_EJERCICIO FECHA_CONCESIÓN BENEFICIARIO  \
# 0           2024      19/09/2024          NaN
# 1           2024      09/09/2024    B98881253
# 2           2024      03/09/2024    P0300500F
# 3           2024      03/09/2024    G85563302
# 4           2024      03/09/2024    G54636261
# ..           ...             ...          ...
# 70          2024      02/09/2024          NaN
# 71          2024      02/09/2024          NaN
# 72          2024      02/09/2024    B96467345
# 73          2024      02/09/2024    B97228993
# 74          2024      02/09/2024    B98706799
#
#                                                NOMBRE  COD_CONVOCATORIA  \
# 0   PERSONA FÍSICA QUE DESARROLLA ACTIVIDAD ECONÓMICA          49907101
# 1   HERRAMIENTAS Y SUMINISTROS FERRETEROS POWERVAL SL          49907101
# 2                            AYUNTAMIENTO DE ALBATERA          38796278
# 3                                 ASOC INSERTA EMPLEO          55654615
# 4   FUNDACION PRIVADA DISCAPACALL DE LA COMUNITAT ...          55654615
# ..                                                ...               ...
# 70  PERSONA FÍSICA QUE DESARROLLA ACTIVIDAD ECONÓMICA          49875273
# 71  PERSONA FÍSICA QUE DESARROLLA ACTIVIDAD ECONÓMICA          49875273
# 72                                        HISPAGAN SL          49875273
# 73                                    SP LOGISTICS SL          49875273
# 74                                MONSALA BUSINESS SL          49875273
#
#                                          CONVOCATORIA CD_TIPO_BENEFICIARIO  \
# 0   UCRANIA - Aportación económica al fondo de pro...                  PFA
# 1   UCRANIA - Aportación económica al fondo de pro...                  PFA
# 2   T1132000 "Atención primaria de carácter especi...                  JSA
# 3   DECRETO 54/2024, de 13 de mayo, del Consell, d...                  JSA
# 4   DECRETO 54/2024, de 13 de mayo, del Consell, d...                  PFA
# ..                                                ...                  ...
# 70  Ayudas para la modernización de empresas priva...                  PFA
# 71  Ayudas para la modernización de empresas priva...                  PFA
# 72  Ayudas para la modernización de empresas priva...                  PFA
# 73  Ayudas para la modernización de empresas priva...                  PFA
# 74  Ayudas para la modernización de empresas priva...                  PFA
#
#                                DS_TIPO_BENEFICIARIO_C  \
# 0   PYME Y PERSONAS FÍSICAS QUE DESARROLLAN ACTIVI...
# 1   PYME Y PERSONAS FÍSICAS QUE DESARROLLAN ACTIVI...
# 2   PERSONAS JURÍDICAS QUE NO DESARROLLAN ACTIVIDA...
# 3   PERSONAS JURÍDICAS QUE NO DESARROLLAN ACTIVIDA...
# 4   PYME Y PERSONAS FÍSICAS QUE DESARROLLAN ACTIVI...
# ..                                                ...
# 70  PYME Y PERSONAS FÍSICAS QUE DESARROLLAN ACTIVI...
# 71  PYME Y PERSONAS FÍSICAS QUE DESARROLLAN ACTIVI...
# 72  PYME Y PERSONAS FÍSICAS QUE DESARROLLAN ACTIVI...
# 73  PYME Y PERSONAS FÍSICAS QUE DESARROLLAN ACTIVI...
# 74  PYME Y PERSONAS FÍSICAS QUE DESARROLLAN ACTIVI...
#
#                                DS_TIPO_BENEFICIARIO_V  CD_FINALIDAD  ...  \
# 0   PYME I PERSONES FÍSIQUES QUE DESENVOLUPEN ACTI...            14  ...
# 1   PYME I PERSONES FÍSIQUES QUE DESENVOLUPEN ACTI...            14  ...
# 2   PERSONES JURÍDIQUES QUE NO DESENVOLUPEN ACTIVI...             5  ...
# 3   PERSONES JURÍDIQUES QUE NO DESENVOLUPEN ACTIVI...             6  ...
# 4   PYME I PERSONES FÍSIQUES QUE DESENVOLUPEN ACTI...             6  ...
# ..                                                ...           ...  ...
# 70  PYME I PERSONES FÍSIQUES QUE DESENVOLUPEN ACTI...            15  ...
# 71  PYME I PERSONES FÍSIQUES QUE DESENVOLUPEN ACTI...            15  ...
# 72  PYME I PERSONES FÍSIQUES QUE DESENVOLUPEN ACTI...            15  ...
# 73  PYME I PERSONES FÍSIQUES QUE DESENVOLUPEN ACTI...            15  ...
# 74  PYME I PERSONES FÍSIQUES QUE DESENVOLUPEN ACTI...            15  ...
#
#    PARTIDO_POLITICO IMP_FINANC_OTROS CD_TIPO_FINAN_EU_CONCACT  \
# 0                 N                0                      NaN
# 1                 N                0                      NaN
# 2                 N                0                      NaN
# 3                 N                0                      NaN
# 4                 N                0                      NaN
# ..              ...              ...                      ...
# 70                N                0                     12.0
# 71                N                0                     12.0
# 72                N                0                     12.0
# 73                N                0                     12.0
# 74                N                0                     12.0
#
#                        DS_TIPO_FINAN_EU_CONCACT_C  \
# 0
# 1
# 2
# 3
# 4
# ..                                            ...
# 70  MRR - MECANISMO DE RECUPERACIÓN Y RESILIENCIA
# 71  MRR - MECANISMO DE RECUPERACIÓN Y RESILIENCIA
# 72  MRR - MECANISMO DE RECUPERACIÓN Y RESILIENCIA
# 73  MRR - MECANISMO DE RECUPERACIÓN Y RESILIENCIA
# 74  MRR - MECANISMO DE RECUPERACIÓN Y RESILIENCIA
#
#                        DS_TIPO_FINAN_EU_CONCACT_V DS_TIPO_FINANCIACION  \
# 0                                                           Autonómica
# 1                                                           Autonómica
# 2                                                           Autonómica
# 3                                                              Estatal
# 4                                                              Estatal
# ..                                            ...                  ...
# 70  MRR - MECANISMO DE RECUPERACIÓN Y RESILIENCIA              Europea
# 71  MRR - MECANISMO DE RECUPERACIÓN Y RESILIENCIA              Europea
# 72  MRR - MECANISMO DE RECUPERACIÓN Y RESILIENCIA              Europea
# 73  MRR - MECANISMO DE RECUPERACIÓN Y RESILIENCIA              Europea
# 74  MRR - MECANISMO DE RECUPERACIÓN Y RESILIENCIA              Europea
#
#    CD_BDNS        DS_PROVINCIA          DS_MUNICIPIO  \
# 0   688113   Valencia/València        Sagunt/Sagunto
# 1   688113   Valencia/València              València
# 2   687699    Alicante/Alacant              Albatera
# 3   762667   Valencia/València              València
# 4   762667    Alicante/Alacant                 Dénia
# ..     ...                 ...                   ...
# 70  695036  Castellón/Castelló               Vinaròs
# 71  695036  Castellón/Castelló  Castelló de la Plana
# 72  695036   Valencia/València                Gandia
# 73  695036   Valencia/València                Gandia
# 74  695036   Valencia/València                Gandia
#
#                      DS_COMARCA
# 0           El Camp de Morvedre
# 1                      Valencia
# 2   El Baix Segura/La Vega Baja
# 3                      Valencia
# 4                La Marina Alta
# ..                          ...
# 70             El Baix Maestrat
# 71                La Plana Alta
# 72                     La Safor
# 73                     La Safor
# 74                     La Safor
#
# [75 rows x 83 columns]

# %%
print(df.shape)
# Out:
# (75, 83)

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# CD_EJERCICIO - 0%
# FECHA_CONCESIÓN - 0%
# BENEFICIARIO - 29%
# NOMBRE - 0%
# COD_CONVOCATORIA - 0%
# CONVOCATORIA - 0%
# CD_TIPO_BENEFICIARIO - 0%
# DS_TIPO_BENEFICIARIO_C - 0%
# DS_TIPO_BENEFICIARIO_V - 0%
# CD_FINALIDAD - 0%
# DS_FINALIDAD_C - 0%
# DS_FINALIDAD_V - 0%
# CD_CONCEDENTE - 0%
# DS_CONCEDENTE_C - 0%
# DS_CONCEDENTE_V - 0%
# CD_TIPO_CONCESION - 0%
# DS_TIPO_CONCESION_C - 0%
# DS_TIPO_CONCESION_V - 0%
# CD_CAPITULO - 0%
# DS_CAPITULO_C - 100%
# DS_CAPITULO_V - 100%
# LINEA_AGREGADA_C - 100%
# LINEA_AGREGADA_V - 100%
# CD_LINEA - 100%
# DS_LINEA_C - 100%
# DS_LINEA_V - 100%
# CD_SUBLINEA - 100%
# DS_SUBLINEA_C - 100%
# DS_SUBLINEA_V - 100%
# IMPORTE - 0%
# PAGADO - 0%
# REINTEGROS - 0%
# DEVOLUCIONES - 0%
# CD_REGION - 0%
# DS_REGION_C - 0%
# DS_REGION_V - 0%
# CD_SECTOR - 24%
# DS_SECTOR_C - 24%
# DS_SECTOR_V - 24%
# CD_TIPO_AYUDA - 0%
# DS_TIPO_AYUDA_C - 0%
# DS_TIPO_AYUDA_V - 0%
# CD_ENTIDAD - 100%
# DS_ENTIDAD_C - 100%
# DS_ENTIDAD_V - 100%
# CD_CONSELLERIA - 0%
# DS_CONSELLERIA_C - 100%
# DS_CONSELLERIA_V - 100%
# CD_CENTRO_GESTOR - 0%
# DS_CENTRO_GESTOR_C - 100%
# DS_CENTRO_GESTOR_V - 100%
# CD_PROGRAMA - 0%
# DS_PROGRAMA_C - 100%
# DS_PROGRAMA_V - 100%
# CD_SUBPROGRAMA - 0%
# DS_SUBPROGRAMA_C - 100%
# DS_SUBPROGRAMA_V - 100%
# BASE_REGULADORA - 0%
# URL_BASE_C - 0%
# URL_BASE_V - 0%
# IMP_FINANC_LOCAL - 0%
# IMP_FINANC_AUTON - 0%
# IMP_FINANC_ESTAT - 0%
# IMP_FINANC_EUROP - 0%
# URL_PUBLI - 13%
# CD_MOMENTO_JUS - 0%
# DS_MOMENTO_JUS_C - 0%
# DS_MOMENTO_JUS_V - 0%
# CD_IMPACTO_GENERO - 0%
# DS_IMPACTO_GENERO_C - 0%
# DS_IMPACTO_GENERO_V - 0%
# TITULO_EXTRACTO_C - 13%
# TITULO_EXTRACTO_V - 13%
# PARTIDO_POLITICO - 0%
# IMP_FINANC_OTROS - 0%
# CD_TIPO_FINAN_EU_CONCACT - 13%
# DS_TIPO_FINAN_EU_CONCACT_C - 0%
# DS_TIPO_FINAN_EU_CONCACT_V - 0%
# DS_TIPO_FINANCIACION - 0%
# CD_BDNS - 0%
# DS_PROVINCIA - 0%
# DS_MUNICIPIO - 0%
# DS_COMARCA - 0%

# %%
# Cálculo del porcentaje de datos erróneos asumiendo que estos son la suma de los datos faltantes y duplicados

# Cálculo del porcentaje de datos faltantes
missing_percentage = (df.isnull().sum() / len(df)) * 100
total_missing_percentage = missing_percentage.sum() / len(df.columns)


# Cálculo del porcentaje de datos duplicados
num_duplicates = df.duplicated().sum()
total_rows = len(df)
percentage_duplicates = (num_duplicates / total_rows) * 100


# Cálculo del porcentaje de datos incorrectos
total_incorrect_percentage = total_missing_percentage + percentage_duplicates

print("Porcentaje de datos incorrectos:", total_incorrect_percentage)
print("Porcentaje de datos faltantes:", total_missing_percentage)
print("Porcentaje de datos duplicaods:", percentage_duplicates)


def calculate_grade(percentage):
  """Calculates a grade from 1 to 10 based on the percentage.

  Args:
      percentage: The percentage value.

  Returns:
      An integer grade from 1 to 10.
  """
  grade = round(10 - (percentage / 100) * 9)
  return max(1, min(10, grade))  # Nota comprendida en el rango de  1-10


# Cálculo de la nota para cada porcentaje
grade_total_incorrect = calculate_grade(total_incorrect_percentage)
grade_total_missing = calculate_grade(total_missing_percentage)
grade_duplicates = calculate_grade(percentage_duplicates)


print("Nota precisión:", grade_total_incorrect)
print("Nota completitud:", grade_total_missing)
print("Nota unicidad:", grade_duplicates)
# Out:
# Porcentaje de datos incorrectos: 36.49799196787149
# Porcentaje de datos faltantes: 27.164658634538156
# Porcentaje de datos duplicaods: 9.333333333333334
# Nota precisión: 7
# Nota completitud: 8
# Nota unicidad: 9
